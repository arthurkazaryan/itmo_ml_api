# %%
import pandas as pd
import numpy as np
from sklearn.impute import KNNImputer
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv("cirrhosis.csv")
df.head()
# Out:
#    ID  N_Days Status             Drug    Age Sex Ascites Hepatomegaly Spiders  \
# 0   1     400      D  D-penicillamine  21464   F       Y            Y       Y
# 1   2    4500      C  D-penicillamine  20617   F       N            Y       Y
# 2   3    1012      D  D-penicillamine  25594   M       N            N       N
# 3   4    1925      D  D-penicillamine  19994   F       N            Y       Y
# 4   5    1504     CL          Placebo  13918   F       N            Y       Y
#
#   Edema  Bilirubin  Cholesterol  Albumin  Copper  Alk_Phos    SGOT  \
# 0     Y       14.5        261.0     2.60   156.0    1718.0  137.95
# 1     N        1.1        302.0     4.14    54.0    7394.8  113.52
# 2     S        1.4        176.0     3.48   210.0     516.0   96.10
# 3     S        1.8        244.0     2.54    64.0    6121.8   60.63
# 4     N        3.4        279.0     3.53   143.0     671.0  113.15
#
#    Tryglicerides  Platelets  Prothrombin  Stage
# 0          172.0      190.0         12.2    4.0
# 1           88.0      221.0         10.6    3.0
# 2           55.0      151.0         12.0    4.0
# 3           92.0      183.0         10.3    4.0
# 4           72.0      136.0         10.9    3.0

# %% [markdown]
# Задача состоит в обучении модели прогнозирования выживания пациентов с циррозом печени на основе имеющихся данных из исследований, проведенных Майской клиникой (Mayo Clinic) в период с 1974 по 1984 год.
#
# Датасет состоит из численных и категориальных данных. Расшифруем колонки с категориальными данными:
# - Status: 3 класса - C (censored), CL (cencored due to liver tx), D (death)
# - Drug: 2 класса - D-penicillamine, Placebo
# - Sex: 2 класса - M (Male), F (Female)
# - Ascites: N (No), Y (Yes)
# - Hepatomegaly: N (No), Y (Yes)
# - Spiders: N (No), Y (Yes)
# - Edema: N (No), S (present without diuretics or resolved by diuretics), Y (Yes)

# %% [markdown]
# При открытии csv файла заметил пустые поля. Посмотрим в каких колонках они встречаются.

# %%
empty_cols = df.columns[df.isna().any()].tolist()
for col in empty_cols:
    print(df[col].dtype, col)
# Out:
# object Drug
# object Ascites
# object Hepatomegaly
# object Spiders
# float64 Cholesterol
# float64 Copper
# float64 Alk_Phos
# float64 SGOT
# float64 Tryglicerides
# float64 Platelets
# float64 Prothrombin
# float64 Stage

# %% [markdown]
# Выяснили, что числовые данные отсутствуют в колонках Cholesterol, Copper, Alk_Phos, SGOT, Tryglicerides, Platelets, Prothrombin, Stage
#
# Для импутации числовых данных воспользуемся *KNNImputer* из библиотеки sklearn.
# Но перед этим посмотрим на матрицу корреляции, чтобы понять, какие колонки больше всего коррелируют с каждой из колонок с отсутствующими данными. По ним и будем искать KNN.

# %%
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_50ac3_row0_col0, #T_50ac3_row1_col1, #T_50ac3_row2_col2, #T_50ac3_row3_col3, #T_50ac3_row4_col4, #T_50ac3_row5_col5, #T_50ac3_row6_col6, #T_50ac3_row7_col7, #T_50ac3_row8_col8, #T_50ac3_row9_col9, #T_50ac3_row10_col10, #T_50ac3_row11_col11, #T_50ac3_row12_col12 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_50ac3_row0_col1, #T_50ac3_row6_col5 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_50ac3_row0_col2, #T_50ac3_row4_col5, #T_50ac3_row5_col7, #T_50ac3_row9_col11 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_50ac3_row0_col3, #T_50ac3_row0_col12, #T_50ac3_row6_col4 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_50ac3_row0_col4, #T_50ac3_row5_col0 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_50ac3_row0_col5, #T_50ac3_row0_col10, #T_50ac3_row4_col11 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_50ac3_row0_col6, #T_50ac3_row3_col10 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_50ac3_row0_col7, #T_50ac3_row1_col0, #T_50ac3_row1_col3, #T_50ac3_row1_col6, #T_50ac3_row1_col8, #T_50ac3_row1_col9, #T_50ac3_row1_col12, #T_50ac3_row2_col4, #T_50ac3_row3_col1, #T_50ac3_row3_col5, #T_50ac3_row5_col2, #T_50ac3_row5_col11, #T_50ac3_row7_col0, #T_50ac3_row12_col10 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_50ac3_row0_col8, #T_50ac3_row9_col2 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_50ac3_row0_col9 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_50ac3_row0_col11, #T_50ac3_row5_col8, #T_50ac3_row12_col5 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_50ac3_row1_col2 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_50ac3_row1_col4 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_50ac3_row1_col5 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_50ac3_row1_col7, #T_50ac3_row4_col7, #T_50ac3_row4_col9 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_50ac3_row1_col10 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_50ac3_row1_col11, #T_50ac3_row5_col4 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_50ac3_row2_col0, #T_50ac3_row4_col0, #T_50ac3_row7_col9, #T_50ac3_row9_col8 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_50ac3_row2_col1 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_50ac3_row2_col3, #T_50ac3_row12_col7 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_50ac3_row2_col5 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_50ac3_row2_col6 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_50ac3_row2_col7 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_50ac3_row2_col8 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_50ac3_row2_col9, #T_50ac3_row6_col10, #T_50ac3_row11_col9 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_50ac3_row2_col10, #T_50ac3_row10_col12 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_50ac3_row2_col11, #T_50ac3_row7_col4 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_50ac3_row2_col12 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_50ac3_row3_col0 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_50ac3_row3_col2 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_50ac3_row3_col4 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_50ac3_row3_col6, #T_50ac3_row8_col3 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# #T_50ac3_row3_col7, #T_50ac3_row8_col7 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_50ac3_row3_col8 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_50ac3_row3_col9 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_50ac3_row3_col11, #T_50ac3_row11_col6 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_50ac3_row3_col12 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_50ac3_row4_col1, #T_50ac3_row6_col0 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_50ac3_row4_col2 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_50ac3_row4_col3 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# #T_50ac3_row4_col6, #T_50ac3_row10_col5 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_50ac3_row4_col8, #T_50ac3_row9_col6 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_50ac3_row4_col10 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_50ac3_row4_col12, #T_50ac3_row7_col8, #T_50ac3_row11_col8 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_50ac3_row5_col1 {
#   background-color: #f1ccb8;
#   color: #000000;
# }
# #T_50ac3_row5_col3 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_50ac3_row5_col6, #T_50ac3_row8_col5 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_50ac3_row5_col9, #T_50ac3_row5_col12 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_50ac3_row5_col10 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_50ac3_row6_col1, #T_50ac3_row8_col2, #T_50ac3_row10_col2, #T_50ac3_row10_col11 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_50ac3_row6_col2, #T_50ac3_row10_col0 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_50ac3_row6_col3 {
#   background-color: #f3c8b2;
#   color: #000000;
# }
# #T_50ac3_row6_col7 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_50ac3_row6_col8 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_50ac3_row6_col9, #T_50ac3_row9_col4 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_50ac3_row6_col11 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_50ac3_row6_col12 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_50ac3_row7_col1, #T_50ac3_row9_col7 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_50ac3_row7_col2 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_50ac3_row7_col3 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_50ac3_row7_col5, #T_50ac3_row9_col5 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_50ac3_row7_col6 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_50ac3_row7_col10, #T_50ac3_row12_col8 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_50ac3_row7_col11, #T_50ac3_row8_col9, #T_50ac3_row12_col9 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_50ac3_row7_col12 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_50ac3_row8_col0, #T_50ac3_row11_col2 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_50ac3_row8_col1 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_50ac3_row8_col4 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_50ac3_row8_col6 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_50ac3_row8_col10 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_50ac3_row8_col11 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_50ac3_row8_col12 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_50ac3_row9_col0, #T_50ac3_row12_col0 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_50ac3_row9_col1 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_50ac3_row9_col3 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_50ac3_row9_col10 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_50ac3_row9_col12 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_50ac3_row10_col1 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_50ac3_row10_col3 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_50ac3_row10_col4 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_50ac3_row10_col6, #T_50ac3_row10_col9 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_50ac3_row10_col7 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_50ac3_row10_col8, #T_50ac3_row11_col5 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_50ac3_row11_col0 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_50ac3_row11_col1 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_50ac3_row11_col3 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_50ac3_row11_col4 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_50ac3_row11_col7 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_50ac3_row11_col10 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_50ac3_row11_col12 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_50ac3_row12_col1 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_50ac3_row12_col2 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_

# %% [markdown]
# Ниже приведены колонки, у которых наибольшая корреляция к колонкам с числовыми значениями.
#
# - Cholesterol: Bilirubin, SGOT, Tryglicerides;
# - Copper: Bilirubin, SGOT, Tryglicerides;
# - Alk_Phos: Copper, Tryglicerides, Cholesterol;
# - SGOT: Bilirubin, Cholesterol, Copper;
# - Tryglicerides: Bilirubin, Copper, Cholesterol;
# - Platelets: Cholesterol, N_Days, Alk_Phos;
# - Prothrombin: Bilirubin, Copper, Stage;
# - Stage: Copper, Bilirubin, Age.

# %%
# Создаем список колонок, где первая колонка - искомая, а 3 последующие - опора (самая большая корреляция).

impute_cols = [
    ["Cholesterol", "Bilirubin", "SGOT", "Tryglicerides"],
    ["Copper", "Bilirubin", "SGOT", "Tryglicerides"],
    ["Alk_Phos", "Copper", "Tryglicerides", "Cholesterol"],
    ["SGOT", "Bilirubin", "Cholesterol", "Copper"],
    ["Tryglicerides", "Bilirubin", "Copper", "Cholesterol"],
    ["Platelets", "Cholesterol", "N_Days", "Alk_Phos"],
    ["Prothrombin", "Bilirubin", "Copper", "Stage"],
    ["Stage", "Copper", "Bilirubin", "Age"]
]

# %% [markdown]
# В качестве обучающих данных будем использовать только ту часть датасета, в которой совсем нет пропущенных данных в каждой из строк рассматриваемых колонок.
# Далее, исходя из полученного KNNImputer, вставляем данные для рассматриваемой колонки для всего датасета.

# %%
for cols in impute_cols:
    print(f"Вставляем значения для \033[1m{cols[0]}\033[0m, опираясь на \033[1m{', '.join(cols[1:])}\033[0m")
    arr = df.loc[:, cols].dropna(axis="rows").to_numpy()
    print(f"Заполненных значений: {arr.shape[0]}")
    imputer = KNNImputer(n_neighbors=3, weights="uniform")
    imputer.fit(arr)
    df.loc[:, cols[0]] = imputer.transform(df.loc[:, cols].to_numpy())[:, 0]
# Out:
# Вставляем значения для Cholesterol, опираясь на Bilirubin, SGOT, Tryglicerides
# Заполненных значений: 282
# Вставляем значения для Copper, опираясь на Bilirubin, SGOT, Tryglicerides
# Заполненных значений: 280
# Вставляем значения для Alk_Phos, опираясь на Copper, Tryglicerides, Cholesterol
# Заполненных значений: 282
# Вставляем значения для SGOT, опираясь на Bilirubin, Cholesterol, Copper
# Заполненных значений: 312
# Вставляем значения для Tryglicerides, опираясь на Bilirubin, Copper, Cholesterol
# Заполненных значений: 282
# Вставляем значения для Platelets, опираясь на Cholesterol, N_Days, Alk_Phos
# Заполненных значений: 407
# Вставляем значения для Prothrombin, опираясь на Bilirubin, Copper, Stage
# Заполненных значений: 410
# Вставляем значения для Stage, опираясь на Copper, Bilirubin, Age
# Заполненных значений: 412

# %%
# Убедимся, что теперь отсутствуют колонки с пустыми числовыми значениями
empty_cols = df.columns[df.isna().any()].tolist()
for col in empty_cols:
    print(df[col].dtype, col)
# Out:
# object Drug
# object Ascites
# object Hepatomegaly
# object Spiders

# %% [markdown]
# Для таких колонок просто заполним самым частовстречающимся значением, так как время=деньги

# %%
for col in empty_cols:
    df[col].fillna(df[col].mode().values[0], inplace=True)

# %%
# Убедимся, что теперь отсутствуют колонки с пустыми значениями
empty_cols = df.columns[df.isna().any()].tolist()
for col in empty_cols:
    print(df[col].dtype, col)

# %%
df.head()
# Out:
#    ID  N_Days Status             Drug    Age Sex Ascites Hepatomegaly Spiders  \
# 0   1     400      D  D-penicillamine  21464   F       Y            Y       Y
# 1   2    4500      C  D-penicillamine  20617   F       N            Y       Y
# 2   3    1012      D  D-penicillamine  25594   M       N            N       N
# 3   4    1925      D  D-penicillamine  19994   F       N            Y       Y
# 4   5    1504     CL          Placebo  13918   F       N            Y       Y
#
#   Edema  Bilirubin  Cholesterol  Albumin  Copper  Alk_Phos    SGOT  \
# 0     Y       14.5        261.0     2.60   156.0    1718.0  137.95
# 1     N        1.1        302.0     4.14    54.0    7394.8  113.52
# 2     S        1.4        176.0     3.48   210.0     516.0   96.10
# 3     S        1.8        244.0     2.54    64.0    6121.8   60.63
# 4     N        3.4        279.0     3.53   143.0     671.0  113.15
#
#    Tryglicerides  Platelets  Prothrombin  Stage
# 0          172.0      190.0         12.2    4.0
# 1           88.0      221.0         10.6    3.0
# 2           55.0      151.0         12.0    4.0
# 3           92.0      183.0         10.3    4.0
# 4           72.0      136.0         10.9    3.0

# %% [markdown]
# Для колонок с текстовыми значениями в виде классов применим категоризацию данных через LabelEncoder

# %%
for col in df.columns.tolist():
    if df[col].dtype == "object" and col != "Status":
        le = LabelEncoder()
        le.fit(df[col])
        df[col]=le.transform(df[col])

# %%
df["Status"].replace("CL", 0, inplace=True)
df["Status"].replace("C", 0, inplace=True)
df["Status"].replace("D", 1, inplace=True)

# %%
df.head()
# Out:
#    ID  N_Days  Status  Drug    Age  Sex  Ascites  Hepatomegaly  Spiders  \
# 0   1     400       1     0  21464    0        1             1        1
# 1   2    4500       0     0  20617    0        0             1        1
# 2   3    1012       1     0  25594    1        0             0        0
# 3   4    1925       1     0  19994    0        0             1        1
# 4   5    1504       0     1  13918    0        0             1        1
#
#    Edema  Bilirubin  Cholesterol  Albumin  Copper  Alk_Phos    SGOT  \
# 0      2       14.5        261.0     2.60   156.0    1718.0  137.95
# 1      0        1.1        302.0     4.14    54.0    7394.8  113.52
# 2      1        1.4        176.0     3.48   210.0     516.0   96.10
# 3      1        1.8        244.0     2.54    64.0    6121.8   60.63
# 4      0        3.4        279.0     3.53   143.0     671.0  113.15
#
#    Tryglicerides  Platelets  Prothrombin  Stage
# 0          172.0      190.0         12.2    4.0
# 1           88.0      221.0         10.6    3.0
# 2           55.0      151.0         12.0    4.0
# 3           92.0      183.0         10.3    4.0
# 4           72.0      136.0         10.9    3.0

# %% [markdown]
# Имея все числовые данные, построим матрицу корреляции.
# К счастью, для нашей колонки Status есть много колонок, обладающих корошей корреляцией по отношению к ней.

# %%
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_668be_row0_col0, #T_668be_row1_col1, #T_668be_row2_col2, #T_668be_row3_col3, #T_668be_row4_col4, #T_668be_row5_col5, #T_668be_row6_col6, #T_668be_row7_col7, #T_668be_row8_col8, #T_668be_row9_col9, #T_668be_row10_col10, #T_668be_row11_col11, #T_668be_row12_col12, #T_668be_row13_col13, #T_668be_row14_col14, #T_668be_row15_col15, #T_668be_row16_col16, #T_668be_row17_col17, #T_668be_row18_col18, #T_668be_row19_col19 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_668be_row0_col1, #T_668be_row15_col4 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_668be_row0_col2, #T_668be_row4_col15, #T_668be_row9_col11, #T_668be_row12_col10, #T_668be_row12_col13, #T_668be_row18_col17 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_668be_row0_col3, #T_668be_row0_col8, #T_668be_row0_col14, #T_668be_row1_col0, #T_668be_row1_col2, #T_668be_row1_col7, #T_668be_row1_col10, #T_668be_row1_col11, #T_668be_row1_col13, #T_668be_row1_col15, #T_668be_row1_col16, #T_668be_row1_col19, #T_668be_row3_col0, #T_668be_row4_col11, #T_668be_row8_col5, #T_668be_row9_col12, #T_668be_row10_col1, #T_668be_row12_col4, #T_668be_row12_col6, #T_668be_row12_col9, #T_668be_row12_col18, #T_668be_row19_col17 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_668be_row0_col4, #T_668be_row5_col16, #T_668be_row8_col11, #T_668be_row13_col4, #T_668be_row13_col17, #T_668be_row18_col16 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_668be_row0_col5, #T_668be_row12_col16 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_668be_row0_col6, #T_668be_row6_col11, #T_668be_row11_col5, #T_668be_row12_col8, #T_668be_row18_col12 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_668be_row0_col7, #T_668be_row4_col2, #T_668be_row7_col10, #T_668be_row15_col2 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_668be_row0_col9, #T_668be_row0_col11, #T_668be_row8_col12, #T_668be_row15_col5 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_668be_row0_col10, #T_668be_row3_col13, #T_668be_row19_col0 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_668be_row0_col12, #T_668be_row16_col12, #T_668be_row19_col11 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_668be_row0_col13, #T_668be_row10_col0, #T_668be_row16_col0, #T_668be_row16_col18, #T_668be_row19_col16 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_668be_row0_col15, #T_668be_row3_col16 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_668be_row0_col16 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_668be_row0_col17, #T_668be_row6_col0, #T_668be_row12_col14 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_668be_row0_col18 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_668be_row0_col19, #T_668be_row3_col17, #T_668be_row5_col3, #T_668be_row6_col15, #T_668be_row7_col4, #T_668be_row17_col13 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_668be_row1_col3, #T_668be_row1_col17, #T_668be_row10_col14, #T_668be_row13_col11, #T_668be_row14_col15, #T_668be_row14_col19, #T_668be_row15_col6, #T_668be_row16_col8, #T_668be_row16_col15, #T_668be_row18_col3, #T_668be_row19_col3 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_668be_row1_col4, #T_668be_row7_col17, #T_668be_row8_col0, #T_668be_row13_col1 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_668be_row1_col5, #T_668be_row8_col4, #T_668be_row17_col7 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_668be_row1_col6 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_668be_row1_col8, #T_668be_row7_col1, #T_668be_row14_col0 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_668be_row1_col9, #T_668be_row3_col4, #T_668be_row19_col12 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_668be_row1_col12 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# #T_668be_row1_col14, #T_668be_row6_col16 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_668be_row1_col18, #T_668be_row9_col1 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_668be_row2_col0, #T_668be_row7_col12, #T_668be_row12_col19 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_668be_row2_col1, #T_668be_row17_col5 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_668be_row2_col3, #T_668be_row5_col10 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_668be_row2_col4 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_668be_row2_col5, #T_668be_row4_col1 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_668be_row2_col6 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_668be_row2_col7, #T_668be_row13_col6, #T_668be_row15_col19 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_668be_row2_col8, #T_668be_row16_col6, #T_668be_row17_col1 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_668be_row2_col9, #T_668be_row11_col15 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_668be_row2_col10 {
#   background-color: #efcebd;
#   color: #000000;
# }
# #T_668be_row2_col11, #T_668be_row4_col0, #T_668be_row4_col10, #T_668be_row5_col4, #T_668be_row7_col18, #T_668be_row11_col3 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_668be_row2_col12, #T_668be_row6_col17 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_668be_row2_col13 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_668be_row2_col14, #T_668be_row2_col15, #T_668be_row6_col8, #T_668be_row18_col8 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_668be_row2_col16, #T_668be_row8_col18, #T_668be_row11_col17, #T_668be_row13_col18 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_668be_row2_col17, #T_668be_row6_col5, #T_668be_row7_col5, #T_668be_row8_col17, #T_668be_row15_col17, #T_668be_row19_col5 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_668be_row2_col18, #T_668be_row8_col10 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_668be_row2_col19, #T_668be_row10_col6 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_668be_row3_col1, #T_668be_row11_col14 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_668be_row3_col2, #T_668be_row3_col12, #T_668be_row5_col1, #T_668be_row6_col3, #T_668be_row11_col19, #T_668be_row16_col17, #T_668be_row17_col10, #T_668be_row17_col14 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_668be_row3_col5, #T_668be_row4_col17 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_668be_row3_col6, #T_668be_row4_col18, #T_668be_row7_col14, #T_668be_row11_col0, #T_668be_row14_col8, #T_668be_row15_col0, #T_668be_row18_col14 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_668be_row3_col7, #T_668be_row14_col5, #T_668be_row15_col1, #T_668be_row18_col11 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_668be_row3_col8, #T_668be_row7_col9 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_668be_row3_col9, #T_668be_row14_col3, #T_668be_row15_col16 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_668be_row3_col10, #T_668be_row15_col9 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_668be_row3_col11, #T_668be_row11_col18 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_668be_row3_col14 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_668be_row3_col15, #T_668be_row17_col0, #T_668be_row17_col2 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_668be_row3_col18, #T_668be_row5_col15, #T_668be_row6_col14, #T_668be_row9_col16, #T_668be_row11_col6, #T_668be_row18_col1 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_668be_row3_col19, #T_668be_row11_col7 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_668be_row4_col3, #T_668be_row9_col0, #T_668be_row16_col5 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_668be_row4_col5, #T_668be_row7_col16, #T_668be_row18_col15 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_668be_row4_col6, #T_668be_row13_col7, #T_668be_row14_col10 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_668be_row4_col7, #T_668be_row6_col4, #T_668be_row9_col7 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_668be_row4_col8 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_668be_row4_col9, #T_668be_row11_col13, #T_668be_row13_col8, #T_668be_row18_col13 {
#   bac

# %% [markdown]
# Все численные значения (кроме категориальных) нормируем индивидуально для каждой колонки, используя StandardScaler

# %%
for col in ["N_Days", "Age", "Bilirubin", "Cholesterol", "Albumin", "Copper", "Alk_Phos", "SGOT", "Tryglicerides", "Platelets", "Prothrombin"]:
    scaler = StandardScaler()
    df[col] = scaler.fit_transform(df[col].to_numpy().reshape(-1, 1)).reshape(-1)

# %%
df.head()
# Out:
#    ID    N_Days  Status  Drug       Age  Sex  Ascites  Hepatomegaly  Spiders  \
# 0   1 -1.375612       1     0  0.768941    0        1             1        1
# 1   2  2.340341       0     0  0.546706    0        0             1        1
# 2   3 -0.820938       1     0  1.852567    1        0             0        0
# 3   4  0.006542       1     0  0.383244    0        0             1        1
# 4   5 -0.375023       0     1 -1.210972    0        0             1        1
#
#    Edema  Bilirubin  Cholesterol   Albumin    Copper  Alk_Phos      SGOT  \
# 0      2   2.562152    -0.488044 -2.114296  0.723999 -0.118540  0.292738
# 1      0  -0.481759    -0.288171  1.513818 -0.556211  2.845083 -0.174052
# 2      1  -0.413611    -0.902416 -0.041088  1.401758 -0.746055 -0.506900
# 3      1  -0.322748    -0.570918 -2.255651 -0.430700  2.180502 -1.184634
# 4      0   0.040704    -0.400295  0.076708  0.560835 -0.665136 -0.181121
#
#    Tryglicerides  Platelets  Prothrombin  Stage
# 0       0.880896  -0.689611     1.441539    4.0
# 1      -0.585051  -0.372008    -0.129341    3.0
# 2      -1.160959  -1.089176     1.245179    4.0
# 3      -0.515244  -0.761328    -0.423881    4.0
# 4      -0.864279  -1.242855     0.165199    3.0

# %% [markdown]
# Так как задачей является определение выживаемости пациента, в качестве Y мы возьмём колонку "Status".

# %%
X = df.loc[:, df.columns != "Status"].to_numpy()
Y = df.loc[:, "Status"].to_numpy()
print(X.shape)
print(Y.shape)
# Out:
# (418, 19)
# (418,)

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, train_size=0.8)

print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (334, 19)
# (84, 19)
# (334,)
# (84,)

# %% [markdown]
# ## LogisticRegression()
#
# score: 0.798

# %%
model = LogisticRegression()

# %%
model.fit(x_train, y_train)
# Out:
# C:\Users\Arthur\anaconda3\envs\lipsync\lib\site-packages\sklearn\linear_model\_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# LogisticRegression()

# %%
y_pred = model.predict(x_test)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.7976190476190477

# %% [markdown]
# ## RandomForestClassifier()
# score: 0.845

# %%
model = RandomForestClassifier()

# %%
model.fit(x_train, y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = model.predict(x_test)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.8452380952380952

# %% [markdown]
# ## XGBoost
# score: 0.916

# %%
from xgboost import XGBClassifier

# %%
model = XGBClassifier()
model.fit(x_train, y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, predictor='auto', random_state=0,
#               reg_alpha=0, reg_lambda=1, ...)

# %%
y_pred = model.predict(x_test)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.9166666666666666
